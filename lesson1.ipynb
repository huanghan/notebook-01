# %% [markdown]
# 字典的方式初始化Series

# %%
import pandas as pd
d = {'a' : 10, 'b' : 20, 'c' : 30}
s = pd.Series(d) 

print type(s.index.values)
print s.index.values
print (s.values) 
a = s.values
a.ndim
# Out:
# <type 'numpy.ndarray'>
# ['a' 'b' 'c']
# [10 20 30]
# 1

# %%
import tushare as ts
ts.get_k_data("002743")
# Out:
#            date    open   close    high     low    volume    code
# 0    2015-09-24  12.414  12.787  13.320  12.285   39202.0  002743
# 1    2015-09-25  12.489  12.081  12.737  11.827   23074.0  002743
# 2    2015-09-28  12.384  12.424  12.459  11.956   11948.0  002743
# 3    2015-09-29  12.185  12.041  12.324  11.991    7230.0  002743
# 4    2015-09-30  12.155  13.150  13.245  12.155   98812.0  002743
# 5    2015-10-08  13.086  13.175  13.533  12.936  115735.0  002743
# 6    2015-10-09  13.185  13.265  13.359  12.991   96678.0  002743
# 7    2015-10-12  13.145  13.643  13.927  13.145   85654.0  002743
# 8    2015-10-13  13.568  13.484  13.568  13.235   54288.0  002743
# 9    2015-10-14  13.434  13.116  13.583  13.016   43073.0  002743
# 10   2015-10-15  12.986  13.499  13.538  12.981   44508.0  002743
# 11   2015-10-16  13.683  13.922  14.141  13.250   67964.0  002743
# 12   2015-10-19  13.932  13.479  13.971  13.384   53825.0  002743
# ...
