# %% [markdown]
# 字典的方式初始化Series

# %%
import pandas as pd
d = {'a' : 10, 'b' : 20, 'c' : 30}
s = pd.Series(d) 

print type(s.index.values)
print s.index.values
print (s.values) 
a = s.values
a.ndim
# Out:
# <type 'numpy.ndarray'>
# ['a' 'b' 'c']
# [10 20 30]
# 1

# %%
import tushare as ts
ts.get_k_data('600000', ktype='5')
# Out:
#                  date   open  close   high    low   volume    code
# 0    2018-04-26 14:55  11.58  11.58  11.60  11.57   6930.0  600000
# 1    2018-04-26 15:00  11.59  11.57  11.59  11.55  21394.0  600000
# 2    2018-04-27 09:35  11.58  11.60  11.64  11.57  10630.0  600000
# 3    2018-04-27 09:40  11.61  11.61  11.65  11.60   5614.0  600000
# 4    2018-04-27 09:45  11.61  11.64  11.67  11.61   5624.0  600000
# 5    2018-04-27 09:50  11.63  11.65  11.66  11.60   5591.0  600000
# 6    2018-04-27 09:55  11.65  11.64  11.66  11.60   7194.0  600000
# 7    2018-04-27 10:00  11.64  11.59  11.64  11.58   4592.0  600000
# 8    2018-04-27 10:05  11.59  11.60  11.64  11.58   6635.0  600000
# 9    2018-04-27 10:10  11.60  11.62  11.62  11.57   3209.0  600000
# 10   2018-04-27 10:15  11.61  11.62  11.66  11.61   6267.0  600000
# 11   2018-04-27 10:20  11.62  11.65  11.66  11.62   5519.0  600000
# 12   2018-04-27 10:25  11.65  11.61  11.66  11.61   2932.0  600000
# ...
